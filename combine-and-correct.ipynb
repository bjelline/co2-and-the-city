# %%
# %matplotlib inline
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from parse import *

# %%
map_df1 = pd.read_csv("biggest-msa-to-county-mapping.csv")
map_df1.columns
# Out:
# Index([u'Selected MSA', u'MSA/ CMSA Code', u'PMSA Code', u'FIPS State/ County Code', u'Census MCD Code', u'FIPS MCD Code', u'Area', u'Census Population April 1, 2000', u'Census Population  April 1, 1990', u'Change, 1990 to 2000, Number', u'Change, 1990 to 2000, Percent'], dtype='object')

# %%
map_df2 = map_df1
map_df2.columns = [u'MSA according to Glaeser and Kahn', u'MSA/CMSA Code', u'PMSA Code', u'FIPS State/County Code', u'Census MCD Code', u'FIPS MCD Code', u'Name of Area', u'Population', u'Population1990', u'ChangeNumber', u'ChangePercent']
map_df2
# Out:
#      MSA according to Glaeser and Kahn  MSA/CMSA Code  PMSA Code  \
# 0                                  NaN             40        NaN
# 1                                  NaN             40        NaN
# 2                                  NaN             60        NaN
# 3                                  NaN             60        NaN
# 4                                  NaN             60        NaN
# 5                                  NaN             60        NaN
# 6                                  NaN            120        NaN
# 7                                  NaN            120        NaN
# 8                                  NaN            120        NaN
# 9                          Albany, NY             160        NaN
# 10                                 NaN            160        NaN
# 11                                 NaN            160        NaN
# 12                                 NaN            160        NaN
# 13                                 NaN            160        NaN
# 14                                 NaN            160        NaN
# 15                                 NaN            160        NaN
# 16                    Albuquerque, NM             200        NaN
# 17                                 NaN            200        NaN
# 18                                 NaN            200        NaN
# 19                                 NaN            200        NaN
# 20                                 NaN            220        NaN
# 21                                 NaN            220        NaN
# 22                                 NaN            240        NaN
# 23                                 NaN            240        NaN
# 24                                 NaN            240        NaN
# 25                                 NaN            240        NaN
# 26                                 NaN            280        NaN
# 27                                 NaN            280        NaN
# 28                                 NaN            320        NaN
# 29                                 NaN            320        NaN
# ...                                ...            ...        ...
# 1840                               NaN           8960        NaN
# 1841                               NaN           9000        NaN
# 1842                               NaN           9000        NaN
# 1843                               NaN           9000        NaN
# 1844                               NaN           9000        NaN
# 1845                               NaN           9040        NaN
# 1846                               NaN           9040        NaN
# 1847                               NaN           9040        NaN
# 1848                               NaN           9040        NaN
# 1849                               NaN           9080        NaN
# 1850                               NaN           9080        NaN
# 1851                               NaN           9080        NaN
# 1852                               NaN           9140        NaN
# 1853                               NaN           9140        NaN
# 1854                               NaN           9200        NaN
# 1855                               NaN           9200        NaN
# 1856                               NaN           9200        NaN
# 1857                               NaN           9260        NaN
# 1858                               NaN           9260        NaN
# 1859                               NaN           9280        NaN
# 1860                               NaN           9280        NaN
# 1861                               NaN           9320        NaN
# 1862                               NaN           9320        NaN
# 1863                               NaN           9320        NaN
# 1864                               NaN           9320        NaN
# 1865                               NaN           9340        NaN
# 1866                               NaN           9340        NaN
# 1867                               NaN           9340        NaN
# 1868                               NaN           9360        NaN
# 1869                               NaN           9360        NaN
#
#       FIPS State/County Code  Census MCD Code  FIPS MCD Code  \
# 0                        NaN              NaN            NaN
# 1                      48441              NaN            NaN
# 2                        NaN              NaN            NaN
# 3                      72003              NaN            NaN
# 4                      72005              NaN            NaN
# 5                      72099              NaN            NaN
# 6                        NaN              NaN            NaN
# 7                      13095              NaN            NaN
# 8                      13177              NaN            NaN
# 9                        NaN              NaN            NaN
# 10                     36001              NaN            NaN
# 11                     36057              NaN            NaN
# 12                     36083              NaN            NaN
# 13                     36091              NaN            NaN
# 14                     36093              NaN            NaN
# 15                     36095              NaN            NaN
# 16                       NaN              NaN            NaN
# 17                     35001              NaN            NaN
# 18                     35043              NaN            NaN
# 19                     35061              NaN            NaN
# 20                       NaN              NaN            NaN
# 21                     22079              NaN            NaN
# 22                       NaN              NaN            NaN
# 23                     42025              NaN            NaN
# 24                     42077              NaN            NaN
# 25                     42095              NaN            NaN
# 26                       NaN              NaN            NaN
# 27                     42013              NaN            NaN
# 28                       NaN              NaN            NaN
# 29                     48375              NaN            NaN
# ...                      ...              ...            ...
# 1840                   12099              NaN            NaN
# 1841                     NaN              NaN            NaN
# 1842                   39013              NaN            NaN
# 1843                   54051              NaN            NaN
# 1844                   54069              NaN            NaN
# 1845                     NaN              NaN            NaN
# 1846                   20015              NaN            NaN
# 1847                   20079              NaN            NaN
# 1848                   20173              NaN            NaN
# 1849                     NaN              NaN            NaN
# 1850                   48009              NaN            NaN
# 1851                   48485              NaN            NaN
# 1852                     NaN              NaN            NaN
# 1853                   42081              NaN            NaN
# 1854                     NaN              NaN            NaN
# 1855                   37019              NaN            NaN
# 1856                   37129              NaN            NaN
# 1857                     NaN              NaN            NaN
# 1858                   53077              NaN            NaN
# 1859                     NaN              NaN            NaN
# 1860                   42133              NaN            NaN
# 1861                     NaN              NaN            NaN
# 1862                   39029              NaN            NaN
# 1863                   39099              NaN            NaN
# 1864                   39155              NaN            NaN
# 1865                     NaN              NaN            NaN
# 1866                    6101              NaN            NaN
# 1867                    6115              NaN            NaN
# 1868                     NaN              NaN            NaN
# 1869                    4027              NaN            NaN
#
#                               Name of Area Population Population1990  \
# 0                          Abilene, TX MSA    126,555        119,655
# 1                            Taylor County    126,555        119,655
# 2                        Aguadilla, PR MSA    146,424        128,172
# 3                         Aguada Municipio     42,042         35,911
# 4                      Aguadilla Municipio     64,685         59,335
# 5                           Moca Municipio     39,697         32,926
# 6                           Albany, GA MSA    120,822        112,561
# 7                         Dougherty County     96,065         96,311
# 8                               Lee County     24,757         16,250
# 9        Albany--Schenectady--Troy, NY MSA    875,583        861,424
# 10                           Albany County    294,565        292,594
# 11                       Montgomery County     49,708         51,981
# 12                       Rensselaer County    152,538        154,429
# 13                         Saratoga County    200,635        181,276
# 14                      Schenectady County    146,555        149,285
# 15                        Schoharie County     31,582         31,859
# 16                     Albuquerque, NM MSA    712,738        589,131
# 17                       Bernalillo County    556,678        480,577
# 18                         Sandoval County     89,908         63,319
# 19                         Valencia County     66,152         45,235
# 20                      Alexandria, LA MSA    126,337        131,556
# 21                          Rapides Parish    126,337        131,556
# 22    Allentown--Bethlehem--Easton, PA MSA    637,958        595,081
# 23                           Carbon County     58,802         56,846
# 24                           Lehigh County    312,090        291,130
# 25                      Northampton County    267,066        247,105
# 26                         Altoona, PA MSA    129,144        130,542
# 27                            Blair County    129,144        130,542
# 28                        Amarillo, TX MSA    217,858        187,547
# 29                           Potter County    113,546         97,874
# ...                                    ...        ...            ...
# 1840                     Palm Beach County  1,131,184        863,518
# 1841                  Wheeling, WV--OH MSA    153,172        159,301
# 1842                    Belmont County, OH     70,226         71,074
# 1843                   Marshall County, WV     35,519         37,356
# 1844                       Ohio County, WV     47,427         50,871
# 1845                       Wichita, KS MSA    545,220        485,270
# 1846                         Butler County     59,482         50,580
# 1847                         Harvey County     32,869         31,028
# 1848                       Sedgwick County    452,869        403,662
# 1849                 Wichita Falls, TX MSA    140,518        130,351
# 1850                         Archer County      8,854          7,973
# 1851                        Wichita County    131,664        122,378
# 1852                  Williamsport, PA MSA    120,044        118,710
# 1853                       Lycoming County    120,044        118,710
# 1854                    Wilmington, NC MSA    233,450        171,269
# 1855                      Brunswick County     73,143         50,985
# 1856                    New Hanover County    160,307        120,284
# 1857                        Yakima, WA MSA    222,581        188,823
# 1858                         Yakima County    222,581        188,823
# 1859                          York, PA MSA    381,751        339,574
# 1860                           York County    381,751        339,574
# 1861            Youngstown--Warren, OH MSA    594,746        600,895
# 1862                     Columbiana County    112,075        108,276
# 1863                       Mahoning County    257,555        264,806
# 1864                       Trumbull County    225,116        227,813
# 1865                     Yuba City, CA MSA    139,149        122,643
# 1866                         Sutter County     78,930         64,415
# 1867                           Yuba County     60,219         58,228
# 1868                          Yuma, AZ MSA    160,026        106,895
# 1869                           Yuma County    160,026        106,895
#
#      ChangeNumber ChangePercent
# 0           6,900         5.80%
# 1           6,900         5.80%
# 2          18,252        14.20%
# 3           6,131        17.10%
# 4           5,350         9.00%
# 5           6,771        20.60%
# 6           8,261         7.30%
# 7            -246        -0.30%
# 8           8,507        52.40%
# 9          14,159         1.60%
# 10          1,971         0.70%
# 11         -2,273        -4.40%
# 12         -1,891        -1.20%
# 13         19,359        10.70%
# 14         -2,730        -1.80%
# 15           -277        -0.90%
# 16        123,607        21.00%
# 17         76,101        15.80%
# 18         26,589        42.00%
# 19         20,917        46.20%
# 20         -5,219        -4.00%
# 21         -5,219        -4.00%
# 22         42,877         7.20%
# 23          1,956         3.40%
# 24         20,960         7.20%
# 25         19,961         8.10%
# 26         -1,398        -1.10%
# 27         -1,398        -1.10%
# 28         30,311        16.20%
# 29         15,672        16.00%
# ...           ...           ...
# 1840      267,666        31.00%
# 1841       -6,129        -3.80%
# 1842         -848        -1.20%
# 1843       -1,837        -4.90%
# 1844       -3,444        -6.80%
# 1845       59,950        12.40%
# 1846        8,902        17.60%
# 1847        1,841         5.90%
# 1848       49,207        12.20%
# 1849       10,167         7.80%
# 1850          881        11.00%
# 1851        9,286         7.60%
# 1852        1,334         1.10%
# 1853        1,334         1.10%
# 1854       62,181        36.30%
# 1855       22,158        43.50%
# 1856       40,023        33.30%
# 1857       33,758        17.90%
# 1858       33,758        17.90%
# 1859       42,177        12.40%
# 1860       42,177        12.40%
# 1861       -6,149        -1.00%
# 1862        3,799         3.50%
# 1863       -7,251        -2.70%
# 1864       -2,697        -1.20%
# 1865       16,506        13.50%
# 1866       14,515        22.50%
# 1867        1,991         3.40%
# 1868       53,131        49.70%
# 1869       53,131        49.70%
#
# [1870 rows x 11 columns]

# %%
map_df3 = map_df2
del(map_df3['Population1990'])
del(map_df3['ChangeNumber'])
del(map_df3['ChangePercent'])
map_df3['Population'] = map_df3['Population'].replace(",","",regex=True).astype(int)

map_df3.dtypes
# Out:
# MSA according to Glaeser and Kahn     object
# MSA/CMSA Code                          int64
# PMSA Code                            float64
# FIPS State/County Code               float64
# Census MCD Code                      float64
# FIPS MCD Code                        float64
# Name of Area                          object
# Population                             int64
# dtype: object

# %%
msa_of_county = {}
msa_of_county_fips = {}
msa_fips_of_county_fips = {}
msa_data = []
county_data = []

row = {}    
msa = None
msa_code = None

i=0

for i, row in map_df3.iterrows():
    if type(row['MSA according to Glaeser and Kahn']) == str:
        #print "Found a MSA %s" % row['Selected MSA'] 
        msa_data.append(dict(row))
        msa = row['MSA according to Glaeser and Kahn']
        msa_code = row['MSA/CMSA Code']
        #print msa_code,msa
    elif row['MSA/CMSA Code'] == msa_code:
        #print row['MSA/ CMSA Code'], row['FIPS State/ County Code'], row['Area']
        msa_of_county[row['Name of Area']] = msa
        
        #print row['FIPS State/ County Code']
        if ~np.isnan(row['FIPS State/County Code']):
            msa_of_county_fips[int(row['FIPS State/County Code'])] = msa
            msa_fips_of_county_fips[int(row['FIPS State/County Code'])] = int(msa_code)
        county_data.append(dict(row))
    lastrow = row
print "found %d MSAs and %d counties in all" % (len(msa_data), len(county_data))
# Out:
# found 60 MSAs and 988 counties in all

# %%
msa_df = pd.DataFrame(msa_data)
del(msa_df['FIPS State/County Code'])
del(msa_df['PMSA Code'])
del(msa_df['Census MCD Code'])
del(msa_df['FIPS MCD Code'])
msa_df.rename(columns={'Population':'Population in MSA'}, inplace=True)

print "created dataframe with %d MSAs" % len(msa_df)
msa_df.dtypes
# Out:
# created dataframe with 60 MSAs
# MSA according to Glaeser and Kahn    object
# MSA/CMSA Code                         int64
# Name of Area                         object
# Population in MSA                     int64
# dtype: object

# %%
msa_df.head()
# Out:
#   MSA according to Glaeser and Kahn  MSA/CMSA Code  \
# 0                       Albany, NY             160
# 1                  Albuquerque, NM             200
# 2                      Atlanta, GA             520
# 3                       Austin, TX             640
# 4                   Birmingham, AL            1000
#
#                         Name of Area  Population in MSA
# 0  Albany--Schenectady--Troy, NY MSA             875583
# 1                Albuquerque, NM MSA             712738
# 2                    Atlanta, GA MSA            4112198
# 3         Austin--San Marcos, TX MSA            1249763
# 4                 Birmingham, AL MSA             921106

# %%
county_df1 = pd.DataFrame(county_data)
del(county_df1['PMSA Code'])
del(county_df1['MSA according to Glaeser and Kahn'])
county_df1.rename(columns={'Population':'Population in County (part)'}, inplace=True)

print "created dataframe with %d counties" % len(county_df1)
county_df1.dtypes
# Out:
# created dataframe with 988 counties
# Census MCD Code                float64
# FIPS MCD Code                  float64
# FIPS State/County Code         float64
# MSA/CMSA Code                    int64
# Name of Area                    object
# Population in County (part)      int64
# dtype: object

# %%
county_df1[county_df1['FIPS State/County Code']==9005]
# Out:
#      Census MCD Code  FIPS MCD Code  FIPS State/County Code  MSA/CMSA Code  \
# 505              NaN            NaN                    9005           3280
# 506                5           2760                    9005           3280
# 507               40          37280                    9005           3280
# 508               60          51350                    9005           3280
# 509               80          60750                    9005           3280
# 510              125          86440                    9005           3280
# 664              NaN            NaN                    9005           5602
# 665               15           8210                    9005           5602
# 666               65          52630                    9005           5602
# 667               85          65930                    9005           5602
# 668              115          79720                    9005           5602
# 734              NaN            NaN                    9005           5602
# 735               10           4930                    9005           5602
# 736              100          75730                    9005           5602
# 737              120          80490                    9005           5602
# 738              130          87910                    9005           5602
#
#                      Name of Area  Population in County (part)
# 505      Litchfield County (part)                        37163
# 506              Barkhamsted town                         3494
# 507                Harwinton town                         5283
# 508             New Hartford town                         6088
# 509                 Plymouth town                        11634
# 510               Winchester town                        10664
# 664      Litchfield County (part)                        34677
# 665              Bridgewater town                         1824
# 666              New Milford town                        27121
# 667                  Roxbury town                         2136
# 668               Washington town                         3596
# 734      Litchfield County (part)                        41784
# 735                Bethlehem town                         3422
# 736                Thomaston town                         7503
# 737                Watertown town                        21661
# 738                 Woodbury town                         9198

# %%
county_df2 = county_df1[ ~np.isnan(county_df1["FIPS State/County Code"]) ]
county_df3 = county_df2[ np.isnan(county_df2["FIPS MCD Code"]) ]

county_df3["FIPS State/County Code"] = county_df3["FIPS State/County Code"].astype('int')
print "Selected dataframe down to %d counties" % len(county_df3)
county_df3[county_df3['FIPS State/County Code']==9005]
# Out:
# Selected dataframe down to 474 counties
#      Census MCD Code  FIPS MCD Code  FIPS State/County Code  MSA/CMSA Code  \
# 505              NaN            NaN                    9005           3280
# 664              NaN            NaN                    9005           5602
# 734              NaN            NaN                    9005           5602
#
#                      Name of Area  Population in County (part)
# 505      Litchfield County (part)                        37163
# 664      Litchfield County (part)                        34677
# 734      Litchfield County (part)                        41784

# %%
county_df4 = county_df3
del(county_df4["Census MCD Code"])
del(county_df4["FIPS MCD Code"])
county_df4[county_df4['FIPS State/County Code']==9005]
# Out:
#      FIPS State/County Code  MSA/CMSA Code                  Name of Area  \
# 505                    9005           3280      Litchfield County (part)
# 664                    9005           5602      Litchfield County (part)
# 734                    9005           5602      Litchfield County (part)
#
#      Population in County (part)
# 505                        37163
# 664                        34677
# 734                        41784

# %%
census_df = pd.read_csv("R10843310_SL050.csv", usecols=["Geo_QName","Geo_FIPS","SE_T003_002","SE_T003_001","SE_T003_003","SE_T020_001"])
census_df.rename(columns={'Geo_QName':'County, State', 
                           'Geo_FIPS': 'FIPS', 
                           'SE_T003_002': "Census Population", 
                           'SE_T003_001': "Population Density", 
                           'SE_T003_003': "Area (Land)", 
                           'SE_T020_001': "Households"}, inplace=True)

census_df.head()
# Out:
#              County, State  FIPS  Census Population  Population Density  \
# 0  Autauga County, Alabama  1001              43671            73.27742
# 1  Baldwin County, Alabama  1003             140415            87.96021
# 2  Barbour County, Alabama  1005              29038            32.81487
# 3     Bibb County, Alabama  1007              20826            33.42723
# 4   Blount County, Alabama  1009              51024            79.03527
#
#    Area (Land)  Households
# 0   595.968043       16003
# 1  1596.346695       55336
# 2   884.903584       10409
# 3   623.025046        7421
# 4   645.585175       19265

# %%
county_and_census_df1 = pd.merge(county_df4, census_df,how="left",left_on="FIPS State/County Code", right_on="FIPS")
county_and_census_df1.head()
# Out:
#    FIPS State/County Code  MSA/CMSA Code            Name of Area  \
# 0                   36001            160           Albany County
# 1                   36057            160       Montgomery County
# 2                   36083            160       Rensselaer County
# 3                   36091            160         Saratoga County
# 4                   36093            160      Schenectady County
#
#    Population in County (part)                 County, State   FIPS  \
# 0                       294565       Albany County, New York  36001
# 1                        49708   Montgomery County, New York  36057
# 2                       152538   Rensselaer County, New York  36083
# 3                       200635     Saratoga County, New York  36091
# 4                       146555  Schenectady County, New York  36093
#
#    Census Population  Population Density  Area (Land)  Households
# 0             294565            562.7425   523.445477      120512
# 1              49708            122.7918   404.815367       20038
# 2             152538            233.2513   653.964222       59894
# 3             200635            247.1349   811.844206       78165
# 4             146555            711.0772   206.102787       59684

# %% [markdown]
# ## split up counties
#
# These Counties occure more than once. they are split up into separate MASs

# %%
parts = county_and_census_df1[county_and_census_df1["Name of Area"].str.contains("part")]
print "%d counties are not containt in whole, but just in parts of MSA" % len(parts)
parts
# Out:
# 47 counties are not containt in whole, but just in parts of MSA
#      FIPS State/County Code  MSA/CMSA Code  \
# 38                    25005           1122
# 39                    25005           1122
# 40                    25005           1122
# 41                    25005           6480
# 42                    25009           1122
# 43                    25009           1122
# 44                    25017           1122
# 45                    25017           1122
# 46                    25017           1122
# 47                    25021           1122
# 48                    25021           1122
# 49                    25023           1122
# 50                    25023           1122
# 51                    25023           1122
# 53                    25027           1122
# 54                    25027           1122
# 55                    25027           1122
# 56                    33015           1122
# 57                    33015           1122
# 58                    33015           1122
# 59                    33015           1122
# 60                    33011           1122
# 61                    33011           1122
# 62                    33011           1122
# 63                    33013           1122
# 64                    23031           1122
# 65                    33017           1122
# 66                     9015           1122
# 67                     9015           3280
# 68                    25013           1122
# 169                   45083           3160
# 170                    9003           3280
# 171                    9005           3280
# 172                    9005           5602
# 173                    9005           5602
# 174                    9007           3280
# 175                    9007           5602
# 176                    9011           3280
# 177                    9013           3280
# 264                    9001           5602
# 265                    9001           5602
# 266                    9001           5602
# 267                    9009           5602
# 268                    9009           5602
# 269                    9009           5602
# 352                   44005           6480
# 354                   44009           6480
#
#                            Name of Area  Population in County (part)  \
# 38            Bristol County, MA (part)                       108350
# 39                Bristol County (part)                        34038
# 40                Bristol County (part)                       159226
# 41            Bristol County, MA (part)                       233064
# 42              Essex County, MA (part)                       458546
# 43              Essex County, MA (part)                       264873
# 44          Middlesex County, MA (part)                      1171779
# 45              Middlesex County (part)                         2845
# 46          Middlesex County, MA (part)                       290772
# 47            Norfolk County, MA (part)                       645865
# 48                Norfolk County (part)                         4443
# 49           Plymouth County, MA (part)                       239872
# 50               Plymouth County (part)                       216978
# 51               Plymouth County (part)                        15972
# 53          Worcester County, MA (part)                        83832
# 54              Worcester County (part)                       139439
# 55          Worcester County, MA (part)                       500104
# 56         Rockingham County, NH (part)                         8778
# 57         Rockingham County, NH (part)                       131357
# 58             Rockingham County (part)                        31829
# 59         Rockingham County, NH (part)                        94376
# 60       Hillsborough County, NH (part)                        10914
# 61           Hillsborough County (part)                       149985
# 62           Hillsborough County (part)                       190949
# 63              Merrimack County (part)                        16564
# 64               York County, ME (part)                        41375
# 65          Strafford County, NH (part)                       104947
# 66            Windham County, CT (part)                         8878
# 67                Windham County (part)                        29205
# 68            Hampden County, MA (part)                         2407
# 169                  Spartanburg County                       253791
# 170              Hartford County (part)                       855171
# 171            Litchfield County (part)                        37163
# 172            Litchfield County (part)                        34677
# 173            Litchfield County (part)                        41784
# 174             Middlesex County (part)                       104442
# 175             Middlesex County (part)                        19112
# 176            New London County (part)                        21458
# 177               Tolland County (part)                       135671
# 264             Fairfield County (part)                       345708
# 265             Fairfield County (part)                       183303
# 266             Fairfield County (part)                       353556
# 267             New Haven County (part)                       113771
# 268             New Haven County (part)                       523037
# 269             New Haven County (part)                       187200
# 352           Newport County, RI (part)                        24475
# 354        Washington County, RI (part)                        91734
#
#                           County, State   FIPS  Census Population  \
# 38        Bristol County, Massachusetts  25005             534678
# 39        Bristol County, Massachusetts  25005             534678
# 40        Bristol County, Massachusetts  25005             534678
# 41        Bristol County, Massachusetts  25005             534678
# 42          Essex County, Massachusetts  25009             723419
# 43          Essex County, Massachusetts  25009             723419
# 44      Middlesex County, Massachusetts  25017            1465396
# 45      Middlesex County, Massachusetts  25017            1465396
# 46      Middlesex County, Massachusetts  25017            1465396
# 47        Norfolk County, Massachusetts  25021             650308
# 48        Norfolk County, Massachusetts  25021             650308
# 49       Plymouth County, Massachusetts  25023             472822
# 50       Plymouth County, Massachusetts  25023             472822
# 51       Plymouth County, Massachusetts  25023             472822
# 53      Worcester County, Massachusetts  25027             750963
# 54      Worcester County, Massachusetts  25027             750963
# 55      Worcester County, Massachusetts  25027             750963
# 56     Rockingham County, New Hampshire  33015             277359
# 57     Rockingham County, New Hampshire  33015             277359
# 58     Rockingham County, New Hampshire  33015             277359
# 59     Rockingham County, New Hampshire  33015             277359
# 60   Hillsborough County, New Hampshire  33011             380841
# 61   Hillsborough County, New Hampshire  33011             380841
# 62   Hillsborough County, New Hampshire  33011             380841
# 63      Merrimack County, New Hampshire  33013             136225
# 64                   York County, Maine  23031             186742
# 65      Strafford County, New Hampshire  33017             112233
# 66          Windham County, Connecticut   9015             109091
# 67          Windham County, Connecticut   9015             109091
# 68        Hampden County, Massachusetts  25013             456228
# 169  Spartanburg County, South Carolina  45083             253791
# 170        Hartford County, Connecticut   9003             857183
# 171      Litchfield County, Connecticut   9005             182193
# 172      Litchfield County, Connecticut   9005             182193
# 173      Litchfield County, Connecticut   9005             182193
# 174       Middlesex County, Connecticut   9007             155071
# 175       Middlesex County, Connecticut   9007             155071
# 176      New London County, Connecticut   9011             259088
# 177         Tolland County, Connecticut   9013             136364
# 264       Fairfield County, Connecticut   9001             882567
# 265       Fairfield County, Connecticut   9001             882567
# 266       Fairfield County, Connecticut   9001             882567
# 267       New Haven County, Connecticut   9009             824008
# 268       New Haven County, Connecticut   9009             824008
# 269       New Haven County, Connecticut   9009             824008
# 352        Newport County, Rhode Island  44005              85433
# 354     Washington County, Rhode Island  44009             123546
#
#      Population Density  Area (Land)  Households
# 38             961.6573   555.996374      205411
# 39             961.6573   555.996374      205411
# 40             961.6573   555.996374      205411
# 41             961.6573   555.996374      205411
# 42            1444.9100   500.667104      275419
# 43            1444.9100   500.667104      275419
# 44            1779.5640   823.457962      561220
# 45            1779.5640   823.457962      561220
# 46            1779.5640   823.457962      561220
# 47            1627.4660   399.583158      248827
# 48            1627.4660   399.583158      248827
# 49             715.4742   660.851198      168361
# 50             715.4742   660.851198      168361
# 51             715.4742   660.851198      168361
# 53             496.3194  1513.063974      283927
# 54             496.3194  1513.063974      283927
# 55             496.3194  1513.063974      283927
# 56             399.0980   694.964641      104529
# 57             399.0980   694.964641      104529
# 58             399.0980   694.964641      104529
# 59             399.0980   694.964641      104529
# 60             434.5709   876.361052      144455
# 61             434.5709   876.361052      144455
# 62             434.5709   876.361052      144455
# 63             145.7840   934.430226       51843
# 64             188.4539   990.915949       74563
# 65             304.3516   368.761060       42581
# 66             212.7554   512.753177       41142
# 67             212.7554   512.753177       41142
# 68             737.7509   618.403878      175288
# 169            312.9648   810.925221       97735
# 170           1165.5380   735.439713      335098
# 171            198.0527   919.921976       71551
# 172            198.0527   919.921976       71551
# 173            198.0527   919.921976       71551
# 174            419.9476   369.262709       61341
# 175            419.9476   369.262709       61341
# 176            389.0707   665.914881       99835
# 177            332.5376   410.070879       49431
# 264           1410.2970   625.802065      324232
# 265           1410.2970   625.802065      324232
# 266           1410.2970   625.802065      324232
# 267           1360.5610   605.638315      319040
# 268           1360.5610   605.638315      319040
# 269           1360.5610   605.638315      319040
# 352            821.1008   104.046913       35228
# 354            371.2830   332.754295       46907

# %%
county_and_census_df2 = county_and_census_df1
county_and_census_df2["county part"] = county_and_census_df2["Population in County (part)"] /  county_and_census_df2["Census Population"] 
county_and_census_df2[county_and_census_df2["MSA/CMSA Code"]==3280]
# Out:
#      FIPS State/County Code  MSA/CMSA Code                  Name of Area  \
# 67                     9015           3280         Windham County (part)
# 170                    9003           3280        Hartford County (part)
# 171                    9005           3280      Litchfield County (part)
# 174                    9007           3280       Middlesex County (part)
# 176                    9011           3280      New London County (part)
# 177                    9013           3280         Tolland County (part)
#
#      Population in County (part)                   County, State  FIPS  \
# 67                         29205     Windham County, Connecticut  9015
# 170                       855171    Hartford County, Connecticut  9003
# 171                        37163  Litchfield County, Connecticut  9005
# 174                       104442   Middlesex County, Connecticut  9007
# 176                        21458  New London County, Connecticut  9011
# 177                       135671     Tolland County, Connecticut  9013
#
#      Census Population  Population Density  Area (Land)  Households  \
# 67              109091            212.7554   512.753177       41142
# 170             857183           1165.5380   735.439713      335098
# 171             182193            198.0527   919.921976       71551
# 174             155071            419.9476   369.262709       61341
# 176             259088            389.0707   665.914881       99835
# 177             136364            332.5376   410.070879       49431
#
#      county part
# 67      0.267712
# 170     0.997653
# 171     0.203976
# 174     0.673511
# 176     0.082821
# 177     0.994918

# %%
county_and_census_df2[county_and_census_df2['FIPS State/County Code']==9005]
# Out:
#      FIPS State/County Code  MSA/CMSA Code                  Name of Area  \
# 171                    9005           3280      Litchfield County (part)
# 172                    9005           5602      Litchfield County (part)
# 173                    9005           5602      Litchfield County (part)
#
#      Population in County (part)                   County, State  \
# 171                        37163  Litchfield County, Connecticut
# 172                        34677  Litchfield County, Connecticut
# 173                        41784  Litchfield County, Connecticut
#
#      Census Population  Population Density  Area (Land)  Households  \
# 171             182193            198.0527    38.274467        2976
# 172             182193            198.0527    33.325038        2591
# 173             182193            198.0527    48.384655        3763
#
#      county part
# 171     0.203976
# 172     0.190331
# 173     0.229339

# %%
county_and_census_df = county_and_census_df2
del(county_and_census_df["FIPS"])
county_and_census_df["Area (Land)"] = county_and_census_df2["Area (Land)"] * county_and_census_df2["county part"]
county_and_census_df["Households"] = (county_and_census_df2["Households"] * county_and_census_df2["county part"]).astype("int")
county_and_census_df[county_and_census_df["MSA/CMSA Code"]==3280]
# Out:
#      FIPS State/County Code  MSA/CMSA Code                  Name of Area  \
# 67                     9015           3280         Windham County (part)
# 170                    9003           3280        Hartford County (part)
# 171                    9005           3280      Litchfield County (part)
# 174                    9007           3280       Middlesex County (part)
# 176                    9011           3280      New London County (part)
# 177                    9013           3280         Tolland County (part)
#
#      Population in County (part)                   County, State  \
# 67                         29205     Windham County, Connecticut
# 170                       855171    Hartford County, Connecticut
# 171                        37163  Litchfield County, Connecticut
# 174                       104442   Middlesex County, Connecticut
# 176                        21458  New London County, Connecticut
# 177                       135671     Tolland County, Connecticut
#
#      Census Population  Population Density  Area (Land)  Households  \
# 67              109091            212.7554    36.748950        2948
# 170             857183           1165.5380   731.991282      333526
# 171             182193            198.0527    38.274467        2976
# 174             155071            419.9476   167.503789       27824
# 176             259088            389.0707     4.567753         684
# 177             136364            332.5376   405.913521       48929
#
#      county part
# 67      0.267712
# 170     0.997653
# 171     0.203976
# 174     0.673511
# 176     0.082821
# 177     0.994918

# %%
emissions_df = pd.read_csv("vulcan.csv", usecols=['State', ' County', ' FIPS', ' Total', 'Commercial', 'Industrial', 'Residential', 'Electricity Prod', 'Onroad', 'Cement', 'Aircraft', 'Airborne', 'Nonroad', 'Pop 2000'])
emissions_df.rename(columns={' County'  :'County', 
                       ' FIPS'    :'FIPS', 
                       ' Total'   :'Total', 
                       'Pop 2000' : "Population whole County According to Vulcan"}, inplace=True)
emissions_df.columns
# Out:
# Index([u'State', u'County', u'FIPS', u'Total', u'Commercial', u'Industrial', u'Residential', u'Electricity Prod', u'Onroad', u'Cement', u'Aircraft', u'Airborne', u'Nonroad', u'Population whole County According to Vulcan'], dtype='object')

# %%
emissions_df[emissions_df["County"]=="Kings"]
# Out:
#      State County   FIPS     Total  Commercial  Industrial  Residential  \
# 199     CA  Kings   6031  0.510490    0.015742    0.273590     0.006977
# 1849    NY  Kings  36047  2.762536    0.304717    0.096474     1.263711
#
#       Electricity Prod    Onroad  Cement  Aircraft  Airborne   Nonroad  \
# 199           0.013762  0.164873       0  0.003917  0.009846  0.021782
# 1849          0.365362  0.591724       0  0.000000  0.000000  0.140547
#
#       Population whole County According to Vulcan
# 199                                        129461
# 1849                                      2465326

# %%
emissions_df.dtypes
# Out:
# State                                           object
# County                                          object
# FIPS                                             int64
# Total                                          float64
# Commercial                                     float64
# Industrial                                     float64
# Residential                                    float64
# Electricity Prod                               float64
# Onroad                                         float64
# Cement                                         float64
# Aircraft                                       float64
# Airborne                                       float64
# Nonroad                                        float64
# Population whole County According to Vulcan      int64
# dtype: object

# %% [markdown]
# ## Merge County and Emission
# This needs to be a left join, as some counties are split up in serveral parts
# for now we will copy the emission data to every part of the county.
# For Las Vegas this works out ok: the three counties that make up Las Vegas
# are all 100% located in Las Vegas.

# %%
county_and_emissions_df1 = pd.merge(county_and_census_df, emissions_df,how="inner",left_on="FIPS State/County Code", right_on="FIPS")
county_and_emissions_df1[county_and_emissions_df1["MSA/CMSA Code"]==4120]
# Out:
#      FIPS State/County Code  MSA/CMSA Code           Name of Area  \
# 206                    4015           4120      Mohave County, AZ
# 207                   32003           4120       Clark County, NV
# 208                   32023           4120         Nye County, NV
#
#      Population in County (part)           County, State  Census Population  \
# 206                       155032  Mohave County, Arizona             155032
# 207                      1375765    Clark County, Nevada            1375765
# 208                        32485      Nye County, Nevada              32485
#
#      Population Density   Area (Land)  Households  county part  \
# 206           11.646350  13311.641005       62809            1
# 207          173.919900   7910.335436      512253            1
# 208            1.790136  18146.662462       13309            1
#
#                         ...                      Commercial Industrial  \
# 206                     ...                        0.022141   0.021084
# 207                     ...                        0.159616   0.152634
# 208                     ...                        0.001589   0.004917
#
#      Residential  Electricity Prod    Onroad  Cement  Aircraft  Airborne  \
# 206     0.024725          0.480383  0.365658       0  0.015338  0.038556
# 207     0.303080          4.420963  0.966720       0  0.144370  0.362901
# 208     0.004806          0.000105  0.026740       0  0.002184  0.005490
#
#       Nonroad  Population whole County According to Vulcan
# 206  0.044863                                       155032
# 207  0.318613                                      1375765
# 208  0.005225                                        32485
#
# [3 rows x 24 columns]

# %% [markdown]
# But now an example where this does not work: In MSA 3280 = Hartford, CT we find only parts
# of Windham and Hartford and Litchfield

# %%
county_and_emissions_df1[county_and_emissions_df1["MSA/CMSA Code"]==3280][["FIPS State/County Code","MSA/CMSA Code","Name of Area","Population in County (part)","Census Population","Population whole County According to Vulcan","county part","Total"]]
# Out:
#      FIPS State/County Code  MSA/CMSA Code                  Name of Area  \
# 67                     9015           3280         Windham County (part)
# 170                    9003           3280        Hartford County (part)
# 171                    9005           3280      Litchfield County (part)
# 174                    9007           3280       Middlesex County (part)
# 176                    9011           3280      New London County (part)
# 177                    9013           3280         Tolland County (part)
#
#      Population in County (part)  Census Population  \
# 67                         29205             109091
# 170                       855171             857183
# 171                        37163             182193
# 174                       104442             155071
# 176                        21458             259088
# 177                       135671             136364
#
#      Population whole County According to Vulcan  county part     Total
# 67                                        109091     0.267712  0.670444
# 170                                       857183     0.997653  2.277994
# 171                                       182193     0.203976  0.415812
# 174                                       155071     0.673511  0.625342
# 176                                       259088     0.082821  0.906677
# 177                                       136364     0.994918  0.353834

# %% [markdown]
# ### Correct the emission data
# If only 20% of Litchfield County is inside this MSA,
# then we only want to count 20% of the emissions here.

# %%
county_and_emissions_df = county_and_emissions_df1
for col in ['Total', 'Commercial', 'Industrial', 'Residential', 'Electricity Prod', 'Onroad', 'Cement', 'Aircraft', 'Airborne', 'Nonroad']:
    county_and_emissions_df["%s Emission" % col] = county_and_emissions_df1[col] * county_and_emissions_df1["county part"]
county_and_emissions_df[county_and_emissions_df["MSA/CMSA Code"]==3280][["FIPS State/County Code","MSA/CMSA Code","Name of Area","Population in County (part)","Census Population","Population whole County According to Vulcan","county part","Total Emission"]]
# Out:
#      FIPS State/County Code  MSA/CMSA Code                  Name of Area  \
# 67                     9015           3280         Windham County (part)
# 170                    9003           3280        Hartford County (part)
# 171                    9005           3280      Litchfield County (part)
# 174                    9007           3280       Middlesex County (part)
# 176                    9011           3280      New London County (part)
# 177                    9013           3280         Tolland County (part)
#
#      Population in County (part)  Census Population  \
# 67                         29205             109091
# 170                       855171             857183
# 171                        37163             182193
# 174                       104442             155071
# 176                        21458             259088
# 177                       135671             136364
#
#      Population whole County According to Vulcan  county part  Total Emission
# 67                                        109091     0.267712        0.048051
# 170                                       857183     0.997653        2.267313
# 171                                       182193     0.203976        0.017300
# 174                                       155071     0.673511        0.283666
# 176                                       259088     0.082821        0.006219
# 177                                       136364     0.994918        0.350247

# %% [markdown]
# Check out Brooklyn, just to make sure we did not change any of the data by mistake

# %%
county_and_emissions_df[county_and_emissions_df["County"]=="Kings"][["FIPS State/County Code","MSA/CMSA Code","Name of Area","Population in County (part)","Census Population","Population whole County According to Vulcan","county part","Total Emission"]]
# Out:
#      FIPS State/County Code  MSA/CMSA Code      Name of Area  \
# 280                   36047           5602      Kings County
#
#      Population in County (part)  Census Population  \
# 280                      2465326            2465326
#
#      Population whole County According to Vulcan  county part  Total Emission
# 280                                      2465326            1        2.762536

# %% [markdown]
# check out Las Vegas

# %%
county_and_emissions_df[county_and_emissions_df["MSA/CMSA Code"]==4120]
# Out:
#      FIPS State/County Code  MSA/CMSA Code           Name of Area  \
# 206                    4015           4120      Mohave County, AZ
# 207                   32003           4120       Clark County, NV
# 208                   32023           4120         Nye County, NV
#
#      Population in County (part)           County, State  Census Population  \
# 206                       155032  Mohave County, Arizona             155032
# 207                      1375765    Clark County, Nevada            1375765
# 208                        32485      Nye County, Nevada              32485
#
#      Population Density   Area (Land)  Households  county part  \
# 206           11.646350  13311.641005       62809            1
# 207          173.919900   7910.335436      512253            1
# 208            1.790136  18146.662462       13309            1
#
#            ...        Total Emission Commercial Emission  Industrial Emission  \
# 206        ...              1.012747            0.022141             0.021084
# 207        ...              6.828896            0.159616             0.152634
# 208        ...              0.051056            0.001589             0.004917
#
#      Residential Emission  Electricity Prod Emission  Onroad Emission  \
# 206              0.024725                   0.480383         0.365658
# 207              0.303080                   4.420963         0.966720
# 208              0.004806                   0.000105         0.026740
#
#      Cement Emission  Aircraft Emission  Airborne Emission  Nonroad Emission
# 206                0           0.015338           0.038556          0.044863
# 207                0           0.144370           0.362901          0.318613
# 208                0           0.002184           0.005490          0.005225
#
# [3 rows x 36 columns]

# %%
county_and_emissions_df.dtypes
# Out:
# FIPS State/County Code                           int64
# MSA/CMSA Code                                    int64
# Name of Area                                    object
# Population in County (part)                      int64
# County, State                                   object
# Census Population                                int64
# Population Density                             float64
# Area (Land)                                    float64
# Households                                       int64
# county part                                    float64
# State                                           object
# County                                          object
# FIPS                                             int64
# Total                                          float64
# Commercial                                     float64
# Industrial                                     float64
# Residential                                    float64
# Electricity Prod                               float64
# Onroad                                         float64
# Cement                                         float64
# Aircraft                                       float64
# Airborne                                       float64
# Nonroad                                        float64
# Population whole County According to Vulcan      int64
# MSA FIPS                                         int64
# MSA                                             object
# Total Emission                                 float64
# Commercial Emission                            float64
# Industrial Emission                            float64
# Residential Emission                           float64
# Electricity Prod Emission                      float64
# Onroad Emission                                float64
# Cement Emission                                float64
# Aircraft Emission                              float64
# Airborne Emission                              float64
# Nonroad Emission                               float64
# dtype: object

# %%
msa_of_county_fips.values()[0:10]
# Out:
# ['Greenville, SC ',
#  'Greenville, SC ',
#  'Charlotte, NC',
#  'Nashville, TN ',
#  'Portland, OR ',
#  'New York, NY ',
#  'Portland, OR ',
#  'Memphis, TN ',
#  'Nashville, TN ',
#  'Memphis, TN ']

# %% [markdown]
# ### Add MSA Name and MSA FIPS
# to the county data

# %%
county_and_emissions_df2 = county_and_emissions_df
county_and_emissions_df2["MSA FIPS"] = county_and_emissions_df2.FIPS.replace(msa_fips_of_county_fips)
county_and_emissions_df2["MSA"]      = county_and_emissions_df2.FIPS.replace(msa_of_county_fips)
county_and_emissions_df2[county_and_emissions_df2["MSA/CMSA Code"]==4120][["Name of Area", "FIPS","MSA", "MSA FIPS", "Population in County (part)", "Total"]]
# Out:
#               Name of Area   FIPS             MSA  MSA FIPS  \
# 206      Mohave County, AZ   4015  Las Vegas, NV       4120
# 207       Clark County, NV  32003  Las Vegas, NV       4120
# 208         Nye County, NV  32023  Las Vegas, NV       4120
#
#      Population in County (part)     Total
# 206                       155032  1.012747
# 207                      1375765  6.828896
# 208                        32485  0.051056

# %%
county_and_emissions_df2.columns
# Out:
# Index([u'FIPS State/County Code', u'MSA/CMSA Code', u'Name of Area', u'Population in County (part)', u'County, State', u'Census Population', u'Population Density', u'Area (Land)', u'Households', u'county part', u'State', u'County', u'FIPS', u'Total', u'Commercial', u'Industrial', u'Residential', u'Electricity Prod', u'Onroad', u'Cement', u'Aircraft', u'Airborne', u'Nonroad', u'Population whole County According to Vulcan', u'MSA FIPS', u'MSA', u'Total Emission', u'Commercial Emission', u'Industrial Emission', u'Residential Emission', u'Electricity Prod Emission', u'Onroad Emission', u'Cement Emission', u'Aircraft Emission', u'Airborne Emission', u'Nonroad Emission'], dtype='object')

# %%
county_and_emissions_df2.groupby(["MSA"]).sum().columns
# Out:
# Index([u'FIPS State/County Code', u'MSA/CMSA Code', u'Population in County (part)', u'Census Population', u'Population Density', u'Area (Land)', u'Households', u'county part', u'FIPS', u'Total', u'Commercial', u'Industrial', u'Residential', u'Electricity Prod', u'Onroad', u'Cement', u'Aircraft', u'Airborne', u'Nonroad', u'Population whole County According to Vulcan', u'MSA FIPS', u'Total Emission', u'Commercial Emission', u'Industrial Emission', u'Residential Emission', u'Electricity Prod Emission', u'Onroad Emission', u'Cement Emission', u'Aircraft Emission', u'Airborne Emission', u'Nonroad Emission'], dtype='object')

# %%
msa_and_emissions_df = county_and_emissions_df2.groupby(["MSA"]).sum()
del(msa_and_emissions_df['FIPS State/County Code'])
del(msa_and_emissions_df['MSA/CMSA Code'])
del(msa_and_emissions_df['FIPS'])
del(msa_and_emissions_df['MSA FIPS'])
msa_and_emissions_df["MSA FIPS"] = county_and_emissions_df2.groupby(["MSA"])["MSA FIPS"].first()
msa_and_emissions_df["Population Density"] = msa_and_emissions_df["Census Population"] /  msa_and_emissions_df["Area (Land)"]
msa_and_emissions_df.sort("Total Emission").head()
# Out:
#                   Population in County (part)  Census Population  \
# MSA
# Scranton, PA                           624776             624776
# Fresno, CA                             922516             922516
# Syracuse, NY                           732117             732117
# Albuquerque, NM                        712738             712738
# Tucson, AZ                             843746             843746
#
#                   Population Density  Area (Land)  Households  county part  \
# MSA
# Scranton, PA              279.894054  2232.187467      252582            4
# Fresno, CA                113.910737  8098.586848      289095            2
# Syracuse, NY              237.497048  3082.636207      282601            4
# Albuquerque, NM           119.928998  5942.999730      275028            3
# Tucson, AZ                 91.848645  9186.265116      332350            1
#
#                      Total  Commercial  Industrial  Residential    ...     \
# MSA                                                                ...
# Scranton, PA      1.834487    0.182058    0.178717     0.376628    ...
# Fresno, CA        2.106239    0.137012    0.238824     0.207865    ...
# Syracuse, NY      2.113574    0.143443    0.202598     0.361280    ...
# Albuquerque, NM   2.141536    0.166847    0.103907     0.276234    ...
# Tucson, AZ        2.195879    0.074105    0.156467     0.154825    ...
#
#                   Commercial Emission  Industrial Emission  \
# MSA
# Scranton, PA                 0.182058             0.178717
# Fresno, CA                   0.137012             0.238824
# Syracuse, NY                 0.143443             0.202598
# Albuquerque, NM              0.166847             0.103907
# Tucson, AZ                   0.074105             0.156467
#
#                   Residential Emission  Electricity Prod Emission  \
# MSA
# Scranton, PA                  0.376628                   0.125642
# Fresno, CA                    0.207865                   0.005087
# Syracuse, NY                  0.361280                   0.181598
# Albuquerque, NM               0.276234                   0.209940
# Tucson, AZ                    0.154825                   0.315218
#
#                   Onroad Emission  Cement Emission  Aircraft Emission  \
# MSA
# Scranton, PA             0.838188         0.000000           0.020357
# Fresno, CA               1.223855         0.000000           0.044271
# Syracuse, NY             1.026997         0.000000           0.029441
# Albuquerque, NM          1.030404         0.040301           0.064095
# Tucson, AZ               1.029196         0.124262           0.065923
#
#                   Airborne Emission  Nonroad Emission  MSA FIPS
# MSA
# Scranton, PA               0.051171          0.061726      7560
# Fresno, CA                 0.111283          0.138042      2840
# Syracuse, NY               0.074006          0.094210      8160
# Albuquerque, NM            0.161114          0.088695       200
# Tucson, AZ                 0.165710          0.110174      8520
#
# [5 rows x 28 columns]

# %%
msa_and_emissions_df[msa_and_emissions_df["MSA FIPS"]==4120]
# Out:
#                 Population in County (part)  Census Population  \
# MSA
# Las Vegas, NV                       1563282            1563282
#
#                 Population Density   Area (Land)  Households  county part  \
# MSA
# Las Vegas, NV            39.708815  39368.638903      588371            3
#
#                    Total  Commercial  Industrial  Residential    ...     \
# MSA                                                              ...
# Las Vegas, NV   7.892699    0.183346    0.178636     0.332611    ...
#
#                 Commercial Emission  Industrial Emission  \
# MSA
# Las Vegas, NV              0.183346             0.178636
#
#                 Residential Emission  Electricity Prod Emission  \
# MSA
# Las Vegas, NV               0.332611                   4.901451
#
#                 Onroad Emission  Cement Emission  Aircraft Emission  \
# MSA
# Las Vegas, NV          1.359118                0           0.161892
#
#                 Airborne Emission  Nonroad Emission  MSA FIPS
# MSA
# Las Vegas, NV            0.406946          0.368701      4120
#
# [1 rows x 28 columns]

# %%
msa_and_emissions_df["Total Emission per capita"] = 1000000 * msa_and_emissions_df["Total Emission"] / msa_and_emissions_df["Census Population"]
msa_and_emissions_df[["Total Emission","Census Population", "Total Emission per capita"]].sort("Total Emission per capita")
# Out:
#                                          Total Emission  Census Population  \
# MSA
# Boston, MA                                    11.887227           14648191
# Providence, RI                                 3.641653            3187031
# Hartford, CT                                   2.676269            1470817
# New York, NY                                  50.132060           25374163
# Fresno, CA                                     2.106239             922516
# Los Angeles-Riverside-Orange County, CA       38.295544           16373645
# West Palm Beach, FL                            2.760300            1131184
# Seattle-Tacoma, WA                             8.941035            3554760
# Portland, OR                                   5.735513            2265223
# Miami-Fort Lauderdale, FL                      9.973997            3876380
# Phoenix, AZ                                    8.441516            3251876
# Tucson, AZ                                     2.195879             843746
# San Diego, CA                                  7.446142            2813833
# San Francisco-Oakland-San Jose, CA            19.517793            7039362
# Syracuse, NY                                   2.113574             732117
# Columbus, OH                                   4.470274            1540157
# Scranton, PA                                   1.834487             624776
# Sacramento, CA                                 5.311139            1796857
# Albuquerque, NM                                2.141536             712738
# Raleigh-Durham, NC                             3.628963            1187941
# Salt Lake City, UT                             4.135059            1333914
# Philadelphia, PA                              19.245583            6188463
# Rochester, NY                                  3.438209            1098201
# Dallas, TX                                    16.789290            5221801
# Dayton, OH                                     3.126957             950558
# Albany, NY                                     3.002046             875583
# Austin, TX                                     4.359559            1249763
# Orlando, FL                                    6.038957            1644561
# Greenville, SC                                 3.546334             962441
# Washington-Baltimore, DC                      28.918195            7608070
# Memphis, TN                                    4.390807            1135614
# Oklahoma City, OK                              4.273581            1083346
# Indianapolis, IN                               6.369563            1607486
# Denver, CO                                    10.368711            2581506
# Charlotte, NC                                  6.184352            1499293
# Norfolk, VA                                    6.629186            1569541
# Milwaukee, WI                                  7.283859            1689572
# Sarasota, FL                                   2.673835             589959
# San Antonio, TX                                7.425948            1592383
# Nashville, TN                                  6.027266            1231311
# Tampa, FL                                     11.731247            2395997
# Chicago, IL                                   45.510282            9157540
# Las Vegas, NV                                  7.892699            1563282
# Atlanta, GA                                   21.083470            4112198
# Buffalo, NY                                    6.111840            1170111
# Detroit, MI                                   28.699424            5456428
# Pittsburgh, PA                                12.731676            2358695
# Kansas City, MO                                9.715041            1776062
# Greensboro, NC                                 7.391705            1251509
# Richmond, VA                                   6.024738             996512
# Grand Rapids, MI                               6.775252            1088514
# Cleveland-Akron, OH                           19.776918            2945831
# Houston, TX                                   33.077030            4669571
# Cincinnati, OH                                14.286545            1979202
# St. Louis, MO                                 19.721282            2603607
# Louisville, KY                                 7.825949            1025598
# New Orleans, LA                               10.672714            1337726
# Minneapolis-St. Paul, MN                      24.211738            2968806
# Tulsa, OK                                      6.892907             803235
# Birmingham, AL                                11.731820             921106
#
#                                          Total Emission per capita
# MSA
# Boston, MA                                                0.811515
# Providence, RI                                            1.142648
# Hartford, CT                                              1.819580
# New York, NY                                              1.975713
# Fresno, CA                                                2.283146
# Los Angeles-Riverside-Orange County, CA                   2.338853
# West Palm Beach, FL                                       2.440187
# Seattle-Tacoma, WA                                        2.515229
# Portland, OR                                              2.531986
# Miami-Fort Lauderdale, FL                                 2.573018
# Phoenix, AZ                                               2.595891
# Tucson, AZ                                                2.602536
# San Diego, CA                                             2.646263
# San Francisco-Oakland-San Jose, CA                        2.772665
# Syracuse, NY                                              2.886934
# Columbus, OH                                              2.902479
# Scranton, PA                                              2.936231
# Sacramento, CA                                            2.955794
# Albuquerque, NM                                           3.004661
# Raleigh-Durham, NC                                        3.054835
# Salt Lake City, UT                                        3.099944
# Philadelphia, PA                                          3.109913
# Rochester, NY                                             3.130765
# Dallas, TX                                                3.215230
# Dayton, OH                                                3.289601
# Albany, NY                                                3.428626
# Austin, TX                                                3.488309
# Orlando, FL                                               3.672079
# Greenville, SC                                            3.684729
# Washington-Baltimore, DC                                  3.800990
# Memphis, TN                                               3.866460
# Oklahoma City, OK                                         3.944798
# Indianapolis, IN                                          3.962438
# Denver, CO                                                4.016536
# Charlotte, NC                                             4.124845
# Norfolk, VA                                               4.223646
# Milwaukee, WI                                             4.311068
# Sarasota, FL                                              4.532238
# San Antonio, TX                                           4.663418
# Nashville, TN                                             4.894999
# Tampa, FL                                                 4.896186
# Chicago, IL                                               4.969706
# Las Vegas, NV                                             5.048801
# Atlanta, GA                                               5.127056
# Buffalo, NY                                               5.223300
# Detroit, MI                                               5.259746
# Pittsburgh, PA                                            5.397763
# Kansas City, MO                                           5.469990
# Greensboro, NC                                            5.906234
# Richmond, VA                                              6.045826
# Grand Rapids, MI                                          6.224313
# Cleveland-Akron, OH                                       6.713528
# Houston, TX                                               7.083526
# Cincinnati, OH                                            7.218336
# St. Louis, MO                                             7.574600
# Louisville, KY                                            7.630620
# New Orleans, LA                                           7.978251
# Minneapolis-St. Paul, MN                                  8.155379
# Tulsa, OK                                                 8.581432
# Birmingham, AL                                           12.736667

# %%
msa_and_emissions_df[msa_and_emissions_df["Total Emission per capita"]<1][["Total Emission","Census Population", "Total Emission per capita"]].sort("Total Emission per capita")
# Out:
#                                          Total Emission  Census Population  \
# MSA
# Boston, MA                                    11.887227           14648191
# New York, NY                                  50.132060           25374163
# Los Angeles-Riverside-Orange County, CA       38.295544           16373645
# San Francisco-Oakland-San Jose, CA            19.517793            7039362
# Philadelphia, PA                              19.245583            6188463
# Dallas, TX                                    16.789290            5221801
# Washington-Baltimore, DC                      28.918195            7608070
# Chicago, IL                                   45.510282            9157540
# Detroit, MI                                   28.699424            5456428
#
#                                          Total Emission per capita
# MSA
# Boston, MA                                                0.811515
# New York, NY                                              1.975713
# Los Angeles-Riverside-Orange County, CA                   2.338853
# San Francisco-Oakland-San Jose, CA                        2.772665
# Philadelphia, PA                                          3.109913
# Dallas, TX                                                3.215230
# Washington-Baltimore, DC                                  3.800990
# Chicago, IL                                               4.969706
# Detroit, MI                                               5.259746

# %%
plt.rcParams['figure.figsize'] = (10.0, 8.0)
with plt.style.context('fivethirtyeight'):
    plt.scatter(msa_and_emissions_df["Census Population"], msa_and_emissions_df["Total Emission"], c="g")
    ax = plt.gca()
    ax.set_title("Total CO2 Emission vs. Population")
    ax.set_xlim(left = 0)
    ax.set_ylim(bottom = 0)
    ax.set_xlabel("Population")
    ax.set_ylabel("Emission in Million Tons")    
    plt.savefig("scatter_emission_vs_population.jpg")

# %%
msa_and_emissions_df["Total Emission per capita"] = 1000000 * msa_and_emissions_df["Total Emission"] / msa_and_emissions_df["Census Population"]
msa_and_emissions_df[["Total Emission","Census Population", "Total Emission per capita"]].sort("Total Emission per capita").to_csv("msa_ranked_by_emissions_per_capita.csv")

# %%
plt.rcParams['figure.figsize'] = (10.0, 8.0)
with plt.style.context('fivethirtyeight'):
    plt.scatter(np.log(msa_and_emissions_df["Census Population"]), np.log(1000000*msa_and_emissions_df["Total Emission"]), c="g")
    ax = plt.gca()
    ax.set_title("Total CO2 Emission vs. Population")
    ax.set_xlim(left = 13)
    ax.set_ylim(bottom = 14)    
    ax.set_xlabel("log Population")
    ax.set_ylabel("log Emission in Million Tons")     
    plt.savefig("scatter_log_emission_vs_log_population.jpg")

# %%
y = np.log(msa_and_emissions_df["Total Emission"]*1000000)
x = np.log(msa_and_emissions_df[["Census Population"]])
x.insert(0, "Offset",1)

model_1 = sm.OLS(y,x).fit()
print model_1.summary()
offset = model_1.params[0]
slope = model_1.params[1]

plt.rcParams['figure.figsize'] = (10.0, 8.0)
with plt.style.context('fivethirtyeight'):
    ax=plt.gca()
    ax.set_aspect('equal')
    ax.set_title("Total CO2 Emission vs. Population")
    ax.set_xlabel("log Population")
    ax.set_ylabel("log Emission in Million Tons")         
    plt.scatter(x['Census Population'], y, c="g")
    line_points =  np.linspace(x['Census Population'].min(), x['Census Population'].max(), 10)
    plt.plot(line_points, slope*line_points + offset)
    plt.savefig("scatter_and_fit_log_emission_vs_log_population.jpg")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Total Emission   R-squared:                       0.688
# Model:                            OLS   Adj. R-squared:                  0.683
# Method:                 Least Squares   F-statistic:                     128.0
# Date:                Mon, 24 Nov 2014   Prob (F-statistic):           2.63e-16
# Time:                        22:53:18   Log-Likelihood:                -38.783
# No. Observations:                  60   AIC:                             81.57
# Df Residuals:                      58   BIC:                             85.75
# Df Model:                           1
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# Offset                3.8276      1.065      3.596      0.001         1.697     5.959
# Census Population     0.8291      0.073     11.313      0.000         0.682     0.976
# ==============================================================================
# Omnibus:                        0.322   Durbin-Watson:                   2.404
# Prob(Omnibus):                  0.851   Jarque-Bera (JB):                0.127
# Skew:                          -0.113   Prob(JB):                        0.938
# Kurtosis:                       3.010   Cond. No.                         256.
# ==============================================================================

# %%
y = np.log(msa_and_emissions_df["Total Emission"]*1000000)
x = pd.DataFrame({"Log Census Population": np.log(msa_and_emissions_df["Census Population"]),
               "Log Population Density": np.log(msa_and_emissions_df["Population Density"])})
x.insert(0, "Offset",1)
x.head()
# Out:
#                   Offset  Log Census Population  Log Population Density
# MSA
# Albany, NY             1              13.682645                5.604827
# Albuquerque, NM        1              13.476869                4.786900
# Atlanta, GA            1              15.229468                6.509530
# Austin, TX             1              14.038464                5.689922
# Birmingham, AL         1              13.733330                5.666608

# %%
model_2 = sm.OLS(y,x).fit()
print model_2.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Total Emission   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.690
# Method:                 Least Squares   F-statistic:                     66.69
# Date:                Mon, 24 Nov 2014   Prob (F-statistic):           1.18e-15
# Time:                        22:58:35   Log-Likelihood:                -37.560
# No. Observations:                  60   AIC:                             81.12
# Df Residuals:                      57   BIC:                             87.40
# Df Model:                           2
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Offset                     3.4532      1.080      3.198      0.002         1.291     5.616
# Log Census Population      0.9195      0.093      9.860      0.000         0.733     1.106
# Log Population Density    -0.1523      0.099     -1.540      0.129        -0.350     0.046
# ==============================================================================
# Omnibus:                        0.527   Durbin-Watson:                   2.507
# Prob(Omnibus):                  0.768   Jarque-Bera (JB):                0.648
# Skew:                           0.065   Prob(JB):                        0.723
# Kurtosis:                       2.508   Cond. No.                         286.
# ==============================================================================
